# %%
import tflite2onnx
import os

# %%
cur_dir = "C:/Users/addinedu/Python"
tflite_path = cur_dir + "/"+ "palm_detection_full.tflite"
onnx_path = cur_dir + "/" + "palm_detection_full.onnx"

# %%
tflite2onnx.convert(tflite_path, onnx_path)
# Out:
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# Data type float16 not supported/tested yet, the generated model may contain error
# ...
